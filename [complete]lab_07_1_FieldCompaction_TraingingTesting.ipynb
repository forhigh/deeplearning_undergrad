# %% [markdown]
# <a href="https://colab.research.google.com/github/forhigh/deeplearning_undergrad/blob/main/%5Bcomplete%5Dlab_07_1_FieldCompaction_TraingingTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab_07_1 Deep Neural Nets
# Field Compaction of Open-Graded Aggregates Training and Testing

# %% [markdown]
# 환경 준비

# %%
from tensorflow.keras.models import Sequential # 전체 라이브러리 중 일부 모듈만 호출
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy as np # 넘파이 라이브러리를 np로 호출하도록 설정

# %% [markdown]
# 데이터 준비

# %%
from google.colab import drive
drive.mount('/content/gdrive')

Data_set = np.loadtxt("/content/gdrive/My Drive/Colab Notebooks/FieldCompaction1.csv", delimiter=',', dtype=np.float32)
X = Data_set[:, 0:2]
Y = Data_set[:, 2:5]
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Traing and Testing Datasets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

# %% [markdown]
# 딥러닝 모델 구조 결정

# %%
model = Sequential()
model.add(Dense(30, input_dim=2, activation='relu'))
model.add(Dense(3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 30)                90
#
#  dense_1 (Dense)             (None, 3)                 93
#
# ...
# Total params: 183
# Trainable params: 183
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 모델 실행 (Fitting)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(X_train, Y_train, epochs=2000)
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 4904.9189
# Epoch 2/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 4892.7026
# Epoch 3/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 4880.8833
# Epoch 4/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 4868.2129
# Epoch 5/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 4855.4780
# Epoch 6/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 4843.1357
# Epoch 7/2000
# 2/2 [==============================] - 0s 4ms/step - loss: 4830.8105
# Epoch 8/2000
# 2/2 [==============================] - 0s 3ms/step - loss: 4818.3691
# Epoch 9/2000
# 2/2 [==============================] - 0s 4ms/step - loss: 4805.2617
# Epoch 10/2000
# 2/2 [==============================] - 0s 4ms/step - loss: 4792.7080
# Epoch 11/2000
# 2/2 [==============================] - 0s 4ms/step - loss: 4779.6655
# Epoch 12/2000
# ...

# %% [markdown]
# Evaluate Trained Model by Testing Dataset

# %%
Y_pred = model.predict(X_test)
Diff = Y_pred-Y_test
Y_pred, Y_test, Diff
# Out:
# 1/1 [==============================] - 0s 14ms/step
# (array([[ 34.10428 ,  18.693787, 142.44948 ],
#         [ 31.49592 ,  16.831066, 111.857834],
#         [ 31.49592 ,  16.831066, 111.857834],
#         [ 38.513977,  21.80347 , 133.54382 ],
#         [ 27.638979,  12.794667,  83.890594],
#         [ 40.752907,  23.32942 , 129.0032  ],
#         [ 30.57962 ,  15.815151, 118.91152 ],
#         [ 29.231207,  14.479395,  90.86301 ],
#         [ 29.231207,  14.479395,  90.86301 ],
#         [ 27.398605,  12.44756 , 104.9704  ],
#         [ 28.314905,  13.463477,  97.9167  ],
#         [ 31.928028,  17.150906, 146.96005 ],
#         [ 25.565998,  10.415728, 119.07779 ],
#         [ 28.747013,  13.783317, 133.01892 ],
#         [ 23.975492,   8.731931, 112.10723 ],
#         [ 38.513977,  21.80347 , 133.54382 ]], dtype=float32),
#  array([[ 33.663307,  16.94277 , 117.71253 ],
#         [ 37.751644,  19.06983 , 106.75197 ],
#         [ 41.822575,  19.38105 , 128.93517 ],
# ...

# %%
score = model.evaluate(X_test, Y_test)
print('Test Loss:', score)
# Out:
# 1/1 [==============================] - 0s 101ms/step - loss: 283.4792
# Test Loss: 283.479248046875

# %% [markdown]
# 모델 저장과 재사용

# %%
model.save('/content/gdrive/My Drive/Colab Notebooks/FieldCompaction_TrainedModel.hdf5')

# %%
from tensorflow.keras.models import Sequential, load_model

# %%
del model

# %%
Y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8646be075e12> in <module>
# ----> 1 Y_pred = model.predict(X_test)
#
# NameError: name 'model' is not defined

# %%
model = load_model('/content/gdrive/My Drive/Colab Notebooks/FieldCompaction_TrainedModel.hdf5')

# %%
Y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 39ms/step
